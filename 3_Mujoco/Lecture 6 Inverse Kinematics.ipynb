# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 逆运动学问题：我们给出铰链末端位置，需要求出两个角度。其中f是非线性的，因此我们用非线性方法--逆运动学求解

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Codes example for Jacobian
