# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Model

# %% [markdown]
# 1. from asset to change texture;use texture in material
# 2. use a slide type joint to make a ball slide

# %%
# 特定约束的运动： 原始代码中的三个关节设置（两个滑动 + 一个铰链）是为了创建一个特定的运动约束。
#这种设置允许球体在 xz 平面上移动并围绕 y 轴旋转，但不允许它在 y 方向上移动或围绕 x 和 z 轴旋转。
<body pos="0 0 0.1'>
    <joint type="slide" axis="1 0 0"/>
    <joint type="slide" axis="0 0 1"/>
    <joint type="hinge" axis="0 -1 0"/>
    <geom type="sphere" size=".1" material="object" />
</body>
